# %% [markdown]
# <a href="https://colab.research.google.com/github/sommurino67-lang/PA1F-grupo-B/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
