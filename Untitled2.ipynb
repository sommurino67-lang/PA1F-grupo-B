# %% [markdown]
# <a href="https://colab.research.google.com/github/sommurino67-lang/PA1F-grupo-B/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int (input("digite sua idade"))

if idade <=17:
  print(f"você é menor de idade")
elif idade <=59:
    print(f"você é um adulto")
else:
    print(f"você é um idoso")
# Out:
# digite sua idade15
# você é menor de idade

# %%
valor = int (input("digite o valor da compra"))

#processamento

calculo = (valor * 10 / 100 )
calculo2 = (valor * 20 / 100)
calculo3 = (valor - calculo)
calculo4 = (valor - calculo2)

if valor <=100:
  print(f"não a desconto para sua compra")

elif valor < 500:
  print(f"seu desconto é{calculo} reais você pagara {calculo3}")

else:
 print(f"seu desconto é {calculo2}reais você pagara {calculo4}")
# Out:
# digite o valor da compra400
# seu desconto é40.0 reais você pagara 360.0

# %%
lado1 = int (input("digite um lado"))
lado2 = int (input("digite um lado"))
lado3 = int (input("digite um lado"))

calculo = (lado1 + lado2)


if calculo > lado3:
  print(f"é um triângulo")

elif calculo < lado3:
  print(f"não é um triângulo")
# Out:
# digite um lado4
# digite um lado4
# digite um lado4
# é um triângulo

# %%
energia = int (input("digite a energia"))

if energia < 30:
  print(f"Crítico")

  if energia <= 70:
   print(f"normal")

elif energia <= 100:
 print(f"saudavel")

else:
    print(f"morto")

# %%
média = int (input("digite a média"))

if média > 7:
 print (f"aprovado")

elif média >= 5:
  print (f"recuperação")

else:
 print (f"reprovado")
# Out:
# digite a média8
# aprovado

# %%
pontuação = int (input("digite sua pontuação"))

calculo = (pontuação * 5 / 100)
calculo = (pontuação * 10 / 100)


if pontuação < 5:
  print ("sem bonus")

elif pontuação <= 7:
  print ("seu bonos é de")
