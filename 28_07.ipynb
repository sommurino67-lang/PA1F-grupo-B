# %% [markdown]
# <a href="https://colab.research.google.com/github/sommurino67-lang/PA1F-grupo-B/blob/main/28_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = int(input("Digite um numero: "))
numero2 = int(input("Digte um número"))

soma = numero1 + numero2
print(soma)
# Out:
# Digite um numero: 1
# Digte um número1
# 2

# %%
numero1 = int(input("Digite um numero: "))
numero2 = int(input("Digte um número"))

multiplicação = numero1 * numero2
print(multiplicação)
# Out:
# Digite um numero: 1
# Digte um número2
# 2

# %%
nota1 = int(input("Digite a primeira nota: "))
nota2 = int(input("Digite a segunda nota: "))

média = (nota1 + nota2) / 2
print(média)
# Out:
# Digite a primeira nota: 7
# Digite a segunda nota: 8
# 7.5

# %%
numero = int(input("Digite um número"))

dobro = numero * 2

triplo = numero * 3



print(dobro, triplo)
# Out:
# Digite um número4
# 8 12

# %%
preço = float(input("Digite o preço do produto: "))

quantidade = int(input("Digite a quantidade do produto: "))

valor_total = preço * quantidade

print(valor_total)
