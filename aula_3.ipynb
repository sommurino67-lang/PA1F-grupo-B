# %% [markdown]
# <a href="https://colab.research.google.com/github/sommurino67-lang/PA1F-grupo-B/blob/main/aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 7
lado2 = 6

#calculo da área
area = lado1 * lado2

#cálculo da áre de um quadrado

areaquadrado = lado1 *lado1

# %%
print (area)
# Out:
# 42

# %%
print (areaquadrado)
# Out:
# 49

# %%
nome = "Miguel"
idade = 15
altura = 3

# %%
print (f":nome : {nome},idade: {idade},altura: {altura}")
# Out:
# :nome : Miguel,idade: 15,altura: 3
